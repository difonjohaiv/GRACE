# %%
from load_data import PrepareData

# %%
data = PrepareData(dataset="R8")
# Out:
# prepare data
# +---------+-----------+-------------+------------+----------+
# |  Nodes  |   Edges   |  Selfloops  |  Isolates  |  覆盖度  |
# +---------+-----------+-------------+------------+----------+
# |  15362  |  1672984  |      0      |     0      |  1.0000  |
# +---------+-----------+-------------+------------+----------+

# %%
data.adj

# %%
data.features

# %%
type(data.adj)
# Out:
# torch.Tensor

# %%
from networkx import graph
